# %% [markdown]
# # Closed form solution in linear regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import make_regression

# %%
X, Y = make_regression(n_samples = 400, n_features = 1, n_informative = 1, noise = 1.8, random_state = 11)

# %%
print(X.shape)
print(Y.shape)
# Out:
# (400, 1)
# (400,)

# %%
# Reshape Y
Y = Y.reshape((-1,1))
print(X.shape)
print(Y.shape)
# Out:
# (400, 1)
# (400, 1)

# %%
#Normalise
X = (X - X.mean())/X.std()

# %%
#Visualise

plt.figure()
plt.scatter(X,Y)
plt.title("Normalized Data")
plt.show()

# %%
ones = np.ones((X.shape[0],1))
X_ = np.hstack((X,ones))
print(X_.shape)
print(X_[:5,:])
# Out:
# (400, 2)
# [[-0.86881353  1.        ]
#  [ 1.04796658  1.        ]
#  [-0.2019676   1.        ]
#  [-0.34017061  1.        ]
#  [ 0.13317349  1.        ]]

# %%
def predict(X,theta):
  return np.dot(X.theta)

# %%
def getThetaClosedForm(X, Y):
  Y = np.mat(Y)  #Convert into Matrix
  FirstPart = np.dot(X.T, X)
  SecondPart = np.dot(X.T, Y)
  theta = np.linalg.pinv(FirstPart)*SecondPart
  return theta

# %%
theta = getThetaClosedForm(X_, Y)
print(theta)
# Out:
# [[19.45877082]
#  [-0.29187892]]

# %%
plt.figure()
plt.scatter(X,Y)
plt.plot(X,predict(X_,theta),color='red',label="Prediction")
plt.legend()
plt.title("Normalized Data")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-b8a59de1a347> in <module>()
#       1 plt.figure()
#       2 plt.scatter(X,Y)
# ----> 3 plt.plot(X,predict(X_,theta),color='red',label="Prediction")
#       4 plt.legend()
#       5 plt.title("Normalized Data")
#
# <ipython-input-13-da48fb37c4ff> in predict(X, theta)
#       1 def predict(X,theta):
# ----> 2   return np.dot(X.theta)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'theta'

# %%
plt.figure()
#plt.scatter(X,Y)
plt.scatter(X,Y)
plt.legend()
plt.title("Normalized Data")
plt.show()
# Out:
# No handles with labels found to put in legend.
